# %% [markdown]
# # 1.14 使用python 計算文章中的字詞頻率

# %%
speech_text='''
As Prepared for Delivery –
Chief Justice Roberts, President Carter, President Clinton, President Bush, President Obama, fellow Americans, and people of the world: thank you.
We, the citizens of America, are now joined in a great national effort to rebuild our country and to restore its promise for all of our people.
Together, we will determine the course of America and the world for years to come.
We will face challenges. We will confront hardships. But we will get the job done.
Every four years, we gather on these steps to carry out the orderly and peaceful transfer of power, and we are grateful to President Obama and First Lady Michelle Obama for their gracious aid throughout this transition. They have been magnificent.
Today’s ceremony, however, has very special meaning. Because today we are not merely transferring power from one Administration to another, or from one party to another – but we are transferring power from Washington, D.C. and giving it back to you, the American People.
For too long, a small group in our nation’s Capital has reaped the rewards of government while the people have borne the cost.
Washington flourished – but the people did not share in its wealth.
Politicians prospered – but the jobs left, and the factories closed.
The establishment protected itself, but not the citizens of our country.
Their victories have not been your victories; their triumphs have not been your triumphs; and while they celebrated in our nation’s Capital, there was little to celebrate for struggling families all across our land.
That all changes – starting right here, and right now, because this moment is your moment: it belongs to you.
It belongs to everyone gathered here today and everyone watching all across America.
This is your day. This is your celebration.
And this, the United States of America, is your country.
What truly matters is not which party controls our government, but whether our government is controlled by the people.
January 20th 2017, will be remembered as the day the people became the rulers of this nation again.
The forgotten men and women of our country will be forgotten no longer.
Everyone is listening to you now.
You came by the tens of millions to become part of a historic movement the likes of which the world has never seen before.
At the center of this movement is a crucial conviction: that a nation exists to serve its citizens.
Americans want great schools for their children, safe neighborhoods for their families, and good jobs for themselves.
These are the just and reasonable demands of a righteous public.
But for too many of our citizens, a different reality exists: Mothers and children trapped in poverty in our inner cities; rusted-out factories scattered like tombstones across the landscape of our nation; an education system, flush with cash, but which leaves our young and beautiful students deprived of knowledge; and the crime and gangs and drugs that have stolen too many lives and robbed our country of so much unrealized potential.
This American carnage stops right here and stops right now.
We are one nation – and their pain is our pain. Their dreams are our dreams; and their success will be our success. We share one heart, one home, and one glorious destiny.
The oath of office I take today is an oath of allegiance to all Americans.
For many decades, we’ve enriched foreign industry at the expense of American industry;
Subsidized the armies of other countries while allowing for the very sad depletion of our military;
We’ve defended other nation’s borders while refusing to defend our own;
And spent trillions of dollars overseas while America’s infrastructure has fallen into disrepair and decay.
We’ve made other countries rich while the wealth, strength, and confidence of our country has disappeared over the horizon.
One by one, the factories shuttered and left our shores, with not even a thought about the millions upon millions of American workers left behind.
The wealth of our middle class has been ripped from their homes and then redistributed across the entire world.
But that is the past. And now we are looking only to the future.
We assembled here today are issuing a new decree to be heard in every city, in every foreign capital, and in every hall of power.
From this day forward, a new vision will govern our land.
From this moment on, it’s going to be America First.
Every decision on trade, on taxes, on immigration, on foreign affairs, will be made to benefit American workers and American families.
We must protect our borders from the ravages of other countries making our products, stealing our companies, and destroying our jobs. Protection will lead to great prosperity and strength.
I will fight for you with every breath in my body – and I will never, ever let you down.
America will start winning again, winning like never before.
We will bring back our jobs. We will bring back our borders. We will bring back our wealth. And we will bring back our dreams.
We will build new roads, and highways, and bridges, and airports, and tunnels, and railways all across our wonderful nation.
We will get our people off of welfare and back to work – rebuilding our country with American hands and American labor.
We will follow two simple rules: Buy American and Hire American.
We will seek friendship and goodwill with the nations of the world – but we do so with the understanding that it is the right of all nations to put their own interests first.
We do not seek to impose our way of life on anyone, but rather to let it shine as an example for everyone to follow.
We will reinforce old alliances and form new ones – and unite the civilized world against Radical Islamic Terrorism, which we will eradicate completely from the face of the Earth.
At the bedrock of our politics will be a total allegiance to the United States of America, and through our loyalty to our country, we will rediscover our loyalty to each other.
When you open your heart to patriotism, there is no room for prejudice.
The Bible tells us, “how good and pleasant it is when God’s people live together in unity.”
We must speak our minds openly, debate our disagreements honestly, but always pursue solidarity.
When America is united, America is totally unstoppable.
There should be no fear – we are protected, and we will always be protected.
We will be protected by the great men and women of our military and law enforcement and, most importantly, we are protected by God.
Finally, we must think big and dream even bigger.
In America, we understand that a nation is only living as long as it is striving.
We will no longer accept politicians who are all talk and no action – constantly complaining but never doing anything about it.
The time for empty talk is over.
Now arrives the hour of action.
Do not let anyone tell you it cannot be done. No challenge can match the heart and fight and spirit of America.
We will not fail. Our country will thrive and prosper again.
We stand at the birth of a new millennium, ready to unlock the mysteries of space, to free the Earth from the miseries of disease, and to harness the energies, industries and technologies of tomorrow.
A new national pride will stir our souls, lift our sights, and heal our divisions.
It is time to remember that old wisdom our soldiers will never forget: that whether we are black or brown or white, we all bleed the same red blood of patriots, we all enjoy the same glorious freedoms, and we all salute the same great American Flag.
And whether a child is born in the urban sprawl of Detroit or the windswept plains of Nebraska, they look up at the same night sky, they fill their heart with the same dreams, and they are infused with the breath of life by the same almighty Creator.
So to all Americans, in every city near and far, small and large, from mountain to mountain, and from ocean to ocean, hear these words:
You will never be ignored again.
Your voice, your hopes, and your dreams, will define our American destiny. And your courage and goodness and love will forever guide us along the way.
Together, We Will Make America Strong Again.
We Will Make America Wealthy Again.
We Will Make America Proud Again.
We Will Make America Safe Again.
And, Yes, Together, We Will Make America Great Again. Thank you, God Bless You, And God Bless America.
'''

# %%
speech=speech_text.lower().split() #處理大小寫

# %%
speech
# Out:
# ['as',
#  'prepared',
#  'for',
#  'delivery',
#  '–',
#  'chief',
#  'justice',
#  'roberts,',
#  'president',
#  'carter,',
#  'president',
#  'clinton,',
#  'president',
#  'bush,',
#  'president',
#  'obama,',
#  'fellow',
#  'americans,',
#  'and',
#  'people',
#  'of',
#  'the',
#  'world:',
#  'thank',
#  'you.',
#  'we,',
#  'the',
#  'citizens',
#  'of',
#  'america,',
#  'are',
#  'now',
#  'joined',
#  'in',
#  'a',
#  'great',
#  'national',
#  'effort',
#  'to',
#  'rebuild',
#  'our',
#  'country',
#  'and',
#  'to',
#  'restore',
#  'its',
#  'promise',
#  'for',
#  'all',
#  'of',
#  'our',
#  'people.',
#  'together,',
#  'we',
#  'will',
#  'determine',
#  'the',
#  'course',
#  'of',
#  'america',
#  'and',
#  'the',
#  'world',
#  'for',
#  'years',
#  'to',
#  'come.',
#  'we',
#  'will',
#  'face',
#  'challenges.',
#  'we',
#  'will',
#  'confront',
#  'hardships.',
#  'but',
#  'we',
#  'will',
#  'get',
#  'the',
#  'job',
#  'done.',
#  'every',
#  'four',
#  'years,',
#  'we',
#  'gather',
#  'on',
#  'these',
#  'steps',
#  'to',
#  'carry',
#  'out',
#  'the',
#  'orderly',
#  'and',
#  'peaceful',
#  'transfer',
#  'of',
#  'power,',
#  'and',
#  'we',
#  'are',
#  'grateful',
#  'to',
#  'president',
#  'obama',
#  'and',
#  'first',
#  'lady',
#  'michelle',
#  'obama',
#  'for',
#  'their',
#  'gracious',
#  'aid',
#  'throughout',
#  'this',
#  'transition.',
#  'they',
#  'have',
#  'been',
#  'magnificent.',
#  'today’s',
#  'ceremony,',
#  'however,',
#  'has',
#  'very',
#  'special',
#  'meaning.',
#  'because',
#  'today',
#  'we',
#  'are',
#  'not',
#  'merely',
#  'transferring',
#  'power',
#  'from',
#  'one',
#  'administration',
#  'to',
#  'another,',
#  'or',
#  'from',
#  'one',
#  'party',
#  'to',
#  'another',
#  '–',
#  'but',
#  'we',
#  'are',
#  'transferring',
#  'power',
#  'from',
#  'washington,',
#  'd.c.',
#  'and',
#  'giving',
#  'it',
#  'back',
#  'to',
#  'you,',
#  'the',
#  'american',
#  'people.',
#  'for',
#  'too',
#  'long,',
#  'a',
#  'small',
#  'group',
#  'in',
#  'our',
#  'nation’s',
#  'capital',
#  'has',
#  'reaped',
#  'the',
#  'rewards',
#  'of',
#  'government',
#  'while',
#  'the',
#  'people',
#  'have',
#  'borne',
#  'the',
#  'cost.',
#  'washington',
#  'flourished',
#  '–',
#  'but',
#  'the',
#  'people',
#  'did',
#  'not',
#  'share',
#  'in',
#  'its',
#  'wealth.',
#  'politicians',
#  'prospered',
#  '–',
#  'but',
#  'the',
#  'jobs',
#  'left,',
#  'and',
#  'the',
#  'factories',
#  'closed.',
#  'the',
#  'establishment',
#  'protected',
#  'itself,',
#  'but',
#  'not',
#  'the',
#  'citizens',
#  'of',
#  'our',
#  'country.',
#  'their',
#  'victories',
#  'have',
#  'not',
#  'been',
#  'your',
#  'victories;',
#  'their',
#  'triumphs',
#  'have',
#  'not',
#  'been',
#  'your',
#  'triumphs;',
#  'and',
#  'while',
#  'they',
#  'celebrated',
#  'in',
#  'our',
#  'nation’s',
#  'capital,',
#  'there',
#  'was',
#  'little',
#  'to',
#  'celebrate',
#  'for',
#  'struggling',
#  'families',
#  'all',
#  'across',
#  'our',
#  'land.',
#  'that',
#  'all',
#  'changes',
#  '–',
#  'starting',
#  'right',
#  'here,',
#  'and',
#  'right',
#  'now,',
#  'because',
#  'this',
#  'moment',
#  'is',
#  'your',
#  'moment:',
#  'it',
#  'belongs',
#  'to',
#  'you.',
#  'it',
#  'belongs',
#  'to',
#  'everyone',
#  'gathered',
#  'here',
#  'today',
#  'and',
#  'everyone',
#  'watching',
#  'all',
#  'across',
#  'america.',
#  'this',
#  'is',
#  'your',
#  'day.',
#  'this',
#  'is',
#  'your',
#  'celebration.',
#  'and',
#  'this,',
#  'the',
#  'united',
#  'states',
#  'of',
#  'america,',
#  'is',
#  'your',
#  'country.',
#  'what',
#  'truly',
#  'matters',
#  'is',
#  'not',
#  'which',
#  'party',
#  'controls',
#  'our',
#  'government,',
#  'but',
#  'whether',
#  'our',
#  'government',
#  'is',
#  'controlled',
#  'by',
#  'the',
#  'people.',
#  'january',
#  '20th',
#  '2017,',
#  'will',
#  'be',
#  'remembered',
#  'as',
#  'the',
#  'day',
#  'the',
#  'people',
#  'became',
#  'the',
#  'rulers',
#  'of',
#  'this',
#  'nation',
#  'again.',
#  'the',
#  'forgotten',
#  'men',
#  'and',
#  'women',
#  'of',
#  'our',
#  'country',
#  'will',
#  'be',
#  'forgotten',
#  'no',
#  'longer.',
#  'everyone',
#  'is',
#  'listening',
#  'to',
#  'you',
#  'now.',
#  'you',
#  'came',
#  'by',
#  'the',
#  'tens',
#  'of',
#  'millions',
#  'to',
#  'become',
#  'part',
#  'of',
#  'a',
#  'historic',
#  'movement',
#  'the',
#  'likes',
#  'of',
#  'which',
#  'the',
#  'world',
#  'has',
#  'never',
#  'seen',
#  'before.',
#  'at',
#  'the',
#  'center',
#  'of',
#  'this',
#  'movement',
#  'is',
#  'a',
#  'crucial',
#  'conviction:',
#  'that',
#  'a',
#  'nation',
#  'exists',
#  'to',
#  'serve',
#  'its',
#  'citizens.',
#  'americans',
#  'want',
#  'great',
#  'schools',
#  'for',
#  'their',
#  'children,',
#  'safe',
#  'neighborhoods',
#  'for',
#  'their',
#  'families,',
#  'and',
#  'good',
#  'jobs',
#  'for',
#  'themselves.',
#  'these',
#  'are',
#  'the',
#  'just',
#  'and',
#  'reasonable',
#  'demands',
#  'of',
#  'a',
#  'righteous',
#  'public.',
#  'but',
#  'for',
#  'too',
#  'many',
#  'of',
#  'our',
#  'citizens,',
#  'a',
#  'different',
#  'reality',
#  'exists:',
#  'mothers',
#  'and',
#  'children',
#  'trapped',
#  'in',
#  'poverty',
#  'in',
#  'our',
#  'inner',
#  'cities;',
#  'rusted-out',
#  'factories',
#  'scattered',
#  'like',
#  'tombstones',
#  'across',
#  'the',
#  'landscape',
#  'of',
#  'our',
#  'nation;',
#  'an',
#  'education',
#  'system,',
#  'flush',
#  'with',
#  'cash,',
#  'but',
#  'which',
#  'leaves',
#  'our',
#  'young',
#  'and',
#  'beautiful',
#  'students',
#  'deprived',
#  'of',
#  'knowledge;',
#  'and',
#  'the',
#  'crime',
#  'and',
#  'gangs',
#  'and',
#  'drugs',
#  'that',
#  'have',
#  'stolen',
#  'too',
#  'many',
#  'lives',
#  'and',
#  'robbed',
#  'our',
#  'country',
#  'of',
#  'so',
#  'much',
#  'unrealized',
#  'potential.',
#  'this',
#  'american',
#  'carnage',
#  'stops',
#  'right',
#  'here',
#  'and',
#  'stops',
#  'right',
#  'now.',
#  'we',
#  'are',
#  'one',
#  'nation',
#  '–',
#  'and',
#  'their',
#  'pain',
#  'is',
#  'our',
#  'pain.',
#  'their',
#  'dreams',
#  'are',
#  'our',
#  'dreams;',
#  'and',
#  'their',
#  'success',
#  'will',
#  'be',
#  'our',
#  'success.',
#  'we',
#  'share',
#  'one',
#  'heart,',
#  'one',
#  'home,',
#  'and',
#  'one',
#  'glorious',
#  'destiny.',
#  'the',
#  'oath',
#  'of',
#  'office',
#  'i',
#  'take',
#  'today',
#  'is',
#  'an',
#  'oath',
#  'of',
#  'allegiance',
#  'to',
#  'all',
#  'americans.',
#  'for',
#  'many',
#  'decades,',
#  'we’ve',
#  'enriched',
#  'foreign',
#  'industry',
#  'at',
#  'the',
#  'expense',
#  'of',
#  'american',
#  'industry;',
#  'subsidized',
#  'the',
#  'armies',
#  'of',
#  'other',
#  'countries',
#  'while',
#  'allowing',
#  'for',
#  'the',
#  'very',
#  'sad',
#  'depletion',
#  'of',
#  'our',
#  'military;',
#  'we’ve',
#  'defended',
#  'other',
#  'nation’s',
#  'borders',
#  'while',
#  'refusing',
#  'to',
#  'defend',
#  'our',
#  'own;',
#  'and',
#  'spent',
#  'trillions',
#  'of',
#  'dollars',
#  'overseas',
#  'while',
#  'america’s',
#  'infrastructure',
#  'has',
#  'fallen',
#  'into',
#  'disrepair',
#  'and',
#  'decay.',
#  'we’ve',
#  'made',
#  'other',
#  'countries',
#  'rich',
#  'while',
#  'the',
#  'wealth,',
#  'strength,',
#  'and',
#  'confidence',
#  'of',
#  'our',
#  'country',
#  'has',
#  'disappeared',
#  'over',
#  'the',
#  'horizon.',
#  'one',
#  'by',
#  'one,',
#  'the',
#  'factories',
#  'shuttered',
#  'and',
#  'left',
#  'our',
#  'shores,',
#  'with',
#  'not',
#  'even',
#  'a',
#  'thought',
#  'about',
#  'the',
#  'millions',
#  'upon',
#  'millions',
#  'of',
#  'american',
#  'workers',
#  'left',
#  'behind.',
#  'the',
#  'wealth',
#  'of',
#  'our',
#  'middle',
#  'class',
#  'has',
#  'been',
#  'ripped',
#  'from',
#  'their',
#  'homes',
#  'and',
#  'then',
#  'redistributed',
#  'across',
#  'the',
#  'entire',
#  'world.',
#  'but',
#  'that',
#  'is',
#  'the',
#  'past.',
#  'and',
#  'now',
#  'we',
#  'are',
#  'looking',
#  'only',
#  'to',
#  'the',
#  'future.',
#  'we',
#  'assembled',
#  'here',
#  'today',
#  'are',
#  'issuing',
#  'a',
#  'new',
#  'decree',
#  'to',
#  'be',
#  'heard',
#  'in',
#  'every',
#  'city,',
#  'in',
#  'every',
#  'foreign',
#  'capital,',
#  'and',
#  'in',
#  'every',
#  'hall',
#  'of',
#  'power.',
#  'from',
#  'this',
#  'day',
#  'forward,',
#  'a',
#  'new',
#  'vision',
#  'will',
#  'govern',
#  'our',
#  'land.',
#  'from',
#  'this',
#  'moment',
#  'on,',
#  'it’s',
#  'going',
#  'to',
#  'be',
#  'america',
#  'first.',
#  'every',
#  'decision',
#  'on',
#  'trade,',
#  'on',
#  'taxes,',
#  'on',
#  'immigration,',
#  'on',
#  'foreign',
#  'affairs,',
#  'will',
#  'be',
#  'made',
#  'to',
#  'benefit',
#  'american',
#  'workers',
#  'and',
#  'american',
#  'families.',
#  'we',
#  'must',
#  'protect',
#  'our',
#  'borders',
#  'from',
#  'the',
#  'ravages',
#  'of',
#  'other',
#  'countries',
#  'making',
#  'our',
#  'products,',
#  'stealing',
#  'our',
#  'companies,',
#  'and',
#  'destroying',
#  'our',
#  'jobs.',
#  'protection',
#  'will',
#  'lead',
#  'to',
#  'great',
#  'prosperity',
#  'and',
#  'strength.',
#  'i',
#  'will',
#  'fight',
#  'for',
#  'you',
#  'with',
#  'every',
#  'breath',
#  'in',
#  'my',
#  'body',
#  '–',
#  'and',
#  'i',
#  'will',
#  'never,',
#  'ever',
#  'let',
#  'you',
#  'down.',
#  'america',
#  'will',
#  'start',
#  'winning',
#  'again,',
#  'winning',
#  'like',
#  'never',
#  'before.',
#  'we',
#  'will',
#  'bring',
#  'back',
#  'our',
#  'jobs.',
#  'we',
#  'will',
#  'bring',
#  'back',
#  'our',
#  'borders.',
#  'we',
#  'will',
#  'bring',
#  'back',
#  'our',
#  'wealth.',
#  'and',
#  'we',
#  'will',
#  'bring',
#  'back',
#  'our',
#  'dreams.',
#  'we',
#  'will',
#  'build',
#  'new',
#  'roads,',
#  'and',
#  'highways,',
#  'and',
#  'bridges,',
#  'and',
#  'airports,',
#  'and',
#  'tunnels,',
#  'and',
#  'railways',
#  'all',
#  'across',
#  'our',
#  'wonderful',
#  'nation.',
#  'we',
#  'will',
#  'get',
#  'our',
#  'people',
#  'off',
#  'of',
#  'welfare',
#  'and',
#  'back',
#  'to',
#  'work',
#  '–',
#  'rebuilding',
#  'our',
#  'country',
#  'with',
#  'american',
#  'hands',
#  'and',
#  'american',
#  'labor.',
#  'we',
#  'will',
#  'follow',
#  'two',
#  'simple',
#  'rules:',
#  'buy',
#  'american',
#  'and',
#  'hire',
#  'american.',
#  'we',
#  'will',
#  'seek',
#  'friendship',
#  'and',
#  'goodwill',
#  'with',
#  'the',
#  'nations',
#  'of',
#  'the',
#  'world',
#  '–',
#  'but',
#  'we',
#  'do',
#  'so',
#  'with',
#  'the',
#  'understanding',
#  'that',
#  'it',
#  'is',
#  'the',
#  'right',
#  'of',
#  'all',
#  'nations',
#  'to',
#  'put',
#  'their',
#  'own',
#  'interests',
#  'first.',
#  'we',
#  'do',
#  'not',
#  'seek',
#  'to',
#  'impose',
#  'our',
#  'way',
#  'of',
#  'life',
#  'on',
#  'anyone,',
#  'but',
#  'rather',
#  'to',
#  'let',
#  'it',
#  'shine',
#  'as',
#  'an',
#  'example',
#  'for',
#  'everyone',
#  'to',
#  'follow.',
#  'we',
#  'will',
#  'reinforce',
#  'old',
#  'alliances',
#  'and',
#  'form',
#  'new',
#  'ones',
#  '–',
#  'and',
#  'unite',
#  'the',
#  'civilized',
#  'world',
#  'against',
#  'radical',
#  'islamic',
#  'terrorism,',
#  'which',
#  'we',
#  'will',
#  'eradicate',
#  'completely',
#  'from',
#  'the',
#  'face',
#  'of',
#  'the',
#  'earth.',
#  'at',
#  'the',
#  'bedrock',
#  'of',
#  'our',
#  'politics',
#  'will',
#  'be',
#  'a',
#  'total',
#  'allegiance',
#  'to',
#  ...]

# %% [markdown]
# ## Word Count(version1)

# %%
dic={}
for word in speech:
    if word not in dic:
        dic[word]=1
    else:
        dic[word]=dic[word] +1

# %%
dic
# Out:
# {'2017,': 1,
#  '20th': 1,
#  'a': 15,
#  'about': 2,
#  'accept': 1,
#  'across': 5,
#  'action': 1,
#  'action.': 1,
#  'administration': 1,
#  'affairs,': 1,
#  'again,': 1,
#  'again.': 8,
#  'against': 1,
#  'aid': 1,
#  'airports,': 1,
#  'all': 12,
#  'allegiance': 2,
#  'alliances': 1,
#  'allowing': 1,
#  'almighty': 1,
#  'along': 1,
#  'always': 2,
#  'america': 10,
#  'america,': 4,
#  'america.': 3,
#  'american': 11,
#  'american.': 1,
#  'americans': 1,
#  'americans,': 2,
#  'americans.': 1,
#  'america’s': 1,
#  'an': 3,
#  'and': 72,
#  'and,': 2,
#  'another': 1,
#  'another,': 1,
#  'anyone': 1,
#  'anyone,': 1,
#  'anything': 1,
#  'are': 14,
#  'armies': 1,
#  'arrives': 1,
#  'as': 5,
#  'assembled': 1,
#  'at': 5,
#  'back': 6,
#  'be': 12,
#  'beautiful': 1,
#  'became': 1,
#  'because': 2,
#  'become': 1,
#  'bedrock': 1,
#  'been': 4,
#  'before.': 2,
#  'behind.': 1,
#  'belongs': 2,
#  'benefit': 1,
#  'bible': 1,
#  'big': 1,
#  'bigger.': 1,
#  'birth': 1,
#  'black': 1,
#  'bleed': 1,
#  'bless': 2,
#  'blood': 1,
#  'body': 1,
#  'borders': 2,
#  'borders.': 1,
#  'born': 1,
#  'borne': 1,
#  'breath': 2,
#  'bridges,': 1,
#  'bring': 4,
#  'brown': 1,
#  'build': 1,
#  'bush,': 1,
#  'but': 13,
#  'buy': 1,
#  'by': 6,
#  'came': 1,
#  'can': 1,
#  'cannot': 1,
#  'capital': 1,
#  'capital,': 2,
#  'carnage': 1,
#  'carry': 1,
#  'carter,': 1,
#  'cash,': 1,
#  'celebrate': 1,
#  'celebrated': 1,
#  'celebration.': 1,
#  'center': 1,
#  'ceremony,': 1,
#  'challenge': 1,
#  'challenges.': 1,
#  'changes': 1,
#  'chief': 1,
#  'child': 1,
#  'children': 1,
#  'children,': 1,
#  'cities;': 1,
#  'citizens': 2,
#  'citizens,': 1,
#  'citizens.': 1,
#  'city': 1,
#  'city,': 1,
#  'civilized': 1,
#  'class': 1,
#  'clinton,': 1,
#  'closed.': 1,
#  'come.': 1,
#  'companies,': 1,
#  'complaining': 1,
#  'completely': 1,
#  'confidence': 1,
#  'confront': 1,
#  'constantly': 1,
#  'controlled': 1,
#  'controls': 1,
#  'conviction:': 1,
#  'cost.': 1,
#  'countries': 3,
#  'country': 6,
#  'country,': 1,
#  'country.': 2,
#  'courage': 1,
#  'course': 1,
#  'creator.': 1,
#  'crime': 1,
#  'crucial': 1,
#  'd.c.': 1,
#  'day': 2,
#  'day.': 1,
#  'debate': 1,
#  'decades,': 1,
#  'decay.': 1,
#  'decision': 1,
#  'decree': 1,
#  'defend': 1,
#  'defended': 1,
#  'define': 1,
#  'delivery': 1,
#  'demands': 1,
#  'depletion': 1,
#  'deprived': 1,
#  'destiny.': 2,
#  'destroying': 1,
#  'determine': 1,
#  'detroit': 1,
#  'did': 1,
#  'different': 1,
#  'disagreements': 1,
#  'disappeared': 1,
#  'disease,': 1,
#  'disrepair': 1,
#  'divisions.': 1,
#  'do': 3,
#  'doing': 1,
#  'dollars': 1,
#  'done.': 2,
#  'down.': 1,
#  'dream': 1,
#  'dreams': 1,
#  'dreams,': 2,
#  'dreams.': 1,
#  'dreams;': 1,
#  'drugs': 1,
#  'each': 1,
#  'earth': 1,
#  'earth.': 1,
#  'education': 1,
#  'effort': 1,
#  'empty': 1,
#  'energies,': 1,
#  'enforcement': 1,
#  'enjoy': 1,
#  'enriched': 1,
#  'entire': 1,
#  'eradicate': 1,
#  'establishment': 1,
#  'even': 2,
#  'ever': 1,
#  'every': 7,
#  'everyone': 4,
#  'example': 1,
#  'exists': 1,
#  'exists:': 1,
#  'expense': 1,
#  'face': 2,
#  'factories': 3,
#  'fail.': 1,
#  'fallen': 1,
#  'families': 1,
#  'families,': 1,
#  'families.': 1,
#  'far,': 1,
#  'fear': 1,
#  'fellow': 1,
#  'fight': 2,
#  'fill': 1,
#  'finally,': 1,
#  'first': 1,
#  'first.': 2,
#  'flag.': 1,
#  'flourished': 1,
#  'flush': 1,
#  'follow': 1,
#  'follow.': 1,
#  'for': 16,
#  'foreign': 3,
#  'forever': 1,
#  'forget:': 1,
#  'forgotten': 2,
#  'form': 1,
#  'forward,': 1,
#  'four': 1,
#  'free': 1,
#  'freedoms,': 1,
#  'friendship': 1,
#  'from': 11,
#  'future.': 1,
#  'gangs': 1,
#  'gather': 1,
#  'gathered': 1,
#  'get': 2,
#  'giving': 1,
#  'glorious': 2,
#  'god': 2,
#  'god.': 1,
#  'god’s': 1,
#  'going': 1,
#  'good': 2,
#  'goodness': 1,
#  'goodwill': 1,
#  'govern': 1,
#  'government': 2,
#  'government,': 1,
#  'gracious': 1,
#  'grateful': 1,
#  'great': 6,
#  'group': 1,
#  'guide': 1,
#  'hall': 1,
#  'hands': 1,
#  'hardships.': 1,
#  'harness': 1,
#  'has': 6,
#  'have': 5,
#  'heal': 1,
#  'hear': 1,
#  'heard': 1,
#  'heart': 3,
#  'heart,': 1,
#  'here': 3,
#  'here,': 1,
#  'highways,': 1,
#  'hire': 1,
#  'historic': 1,
#  'home,': 1,
#  'homes': 1,
#  'honestly,': 1,
#  'hopes,': 1,
#  'horizon.': 1,
#  'hour': 1,
#  'however,': 1,
#  'i': 3,
#  'ignored': 1,
#  'immigration,': 1,
#  'importantly,': 1,
#  'impose': 1,
#  'in': 14,
#  'industries': 1,
#  'industry': 1,
#  'industry;': 1,
#  'infrastructure': 1,
#  'infused': 1,
#  'inner': 1,
#  'interests': 1,
#  'into': 1,
#  'is': 21,
#  'islamic': 1,
#  'issuing': 1,
#  'it': 9,
#  'it.': 1,
#  'its': 3,
#  'itself,': 1,
#  'it’s': 1,
#  'january': 1,
#  'job': 1,
#  'jobs': 2,
#  'jobs.': 2,
#  'joined': 1,
#  'just': 1,
#  'justice': 1,
#  'knowledge;': 1,
#  'labor.': 1,
#  'lady': 1,
#  'land.': 2,
#  'landscape': 1,
#  'large,': 1,
#  'law': 1,
#  'lead': 1,
#  'leaves': 1,
#  'left': 2,
#  'left,': 1,
#  'let': 3,
#  'life': 2,
#  'lift': 1,
#  'like': 2,
#  'likes': 1,
#  'listening': 1,
#  'little': 1,
#  'live': 1,
#  'lives': 1,
#  'living': 1,
#  'long': 1,
#  'long,': 1,
#  'longer': 1,
#  'longer.': 1,
#  'look': 1,
#  'looking': 1,
#  'love': 1,
#  'loyalty': 2,
#  'made': 2,
#  'magnificent.': 1,
#  'make': 5,
#  'making': 1,
#  'many': 3,
#  'match': 1,
#  'matters': 1,
#  'meaning.': 1,
#  'men': 2,
#  'merely': 1,
#  'michelle': 1,
#  'middle': 1,
#  'military': 1,
#  'military;': 1,
#  'millennium,': 1,
#  'millions': 3,
#  'minds': 1,
#  'miseries': 1,
#  'moment': 2,
#  'moment:': 1,
#  'most': 1,
#  'mothers': 1,
#  'mountain': 1,
#  'mountain,': 1,
#  'movement': 2,
#  'much': 1,
#  'must': 3,
#  'my': 1,
#  'mysteries': 1,
#  'nation': 4,
#  'nation.': 1,
#  'nation;': 1,
#  'national': 2,
#  'nations': 2,
#  'nation’s': 3,
#  'near': 1,
#  'nebraska,': 1,
#  'neighborhoods': 1,
#  'never': 5,
#  'never,': 1,
#  'new': 6,
#  'night': 1,
#  'no': 6,
#  'not': 10,
#  'now': 3,
#  'now,': 1,
#  'now.': 2,
#  'oath': 2,
#  'obama': 2,
#  'obama,': 1,
#  'ocean': 1,
#  'ocean,': 1,
#  'of': 48,
#  'off': 1,
#  'office': 1,
#  'old': 2,
#  'on': 6,
#  'on,': 1,
#  'one': 7,
#  'one,': 1,
#  'ones': 1,
#  'only': 2,
#  'open': 1,
#  'openly,': 1,
#  'or': 4,
#  'orderly': 1,
#  'other': 4,
#  'other.': 1,
#  'our': 48,
#  'out': 1,
#  'over': 1,
#  'over.': 1,
#  'overseas': 1,
#  'own': 1,
#  'own;': 1,
#  'pain': 1,
#  'pain.': 1,
#  'part': 1,
#  'party': 2,
#  'past.': 1,
#  'patriotism,': 1,
#  'patriots,': 1,
#  'peaceful': 1,
#  'people': 6,
#  'people.': 3,
#  'plains': 1,
#  'pleasant': 1,
#  'politicians': 2,
#  'politics': 1,
#  'potential.': 1,
#  'poverty': 1,
#  'power': 2,
#  'power,': 1,
#  'power.': 1,
#  'prejudice.': 1,
#  'prepared': 1,
#  'president': 5,
#  'pride': 1,
#  'products,': 1,
#  'promise': 1,
#  'prosper': 1,
#  'prospered': 1,
#  'prosperity': 1,
#  'protect': 1,
#  'protected': 3,
#  'protected,': 1,
#  'protected.': 1,
#  'protection': 1,
#  'proud': 1,
#  'public.': 1,
#  'pursue': 1,
#  'put': 1,
#  'radical': 1,
#  'railways': 1,
#  'rather': 1,
#  'ravages': 1,
#  'ready': 1,
#  'reality': 1,
#  'reaped': 1,
#  'reasonable': 1,
#  'rebuild': 1,
#  'rebuilding': 1,
#  'red': 1,
#  'rediscover': 1,
#  'redistributed': 1,
#  'refusing': 1,
#  'reinforce': 1,
#  'remember': 1,
#  'remembered': 1,
#  'restore': 1,
#  'rewards': 1,
#  'rich': 1,
#  'right': 5,
#  'righteous': 1,
#  'ripped': 1,
#  'roads,': 1,
#  'robbed': 1,
#  'roberts,': 1,
#  'room': 1,
#  'rulers': 1,
#  'rules:': 1,
#  'rusted-out': 1,
#  'sad': 1,
#  'safe': 2,
#  'salute': 1,
#  'same': 6,
#  'scattered': 1,
#  'schools': 1,
#  'seek': 2,
#  'seen': 1,
#  'serve': 1,
#  'share': 2,
#  'shine': 1,
#  'shores,': 1,
#  'should': 1,
#  'shuttered': 1,
#  'sights,': 1,
#  'simple': 1,
#  'sky,': 1,
#  'small': 2,
#  'so': 3,
#  'soldiers': 1,
#  'solidarity.': 1,
#  'souls,': 1,
#  'space,': 1,
#  'speak': 1,
#  'special': 1,
#  'spent': 1,
#  'spirit': 1,
#  'sprawl': 1,
#  'stand': 1,
#  'start': 1,
#  'starting': 1,
#  'states': 2,
#  'stealing': 1,
#  'steps': 1,
#  'stir': 1,
#  'stolen': 1,
#  'stops': 2,
#  'strength,': 1,
#  'strength.': 1,
#  'striving.': 1,
#  'strong': 1,
#  'struggling': 1,
#  'students': 1,
#  'subsidized': 1,
#  'success': 1,
#  'success.': 1,
#  'system,': 1,
#  'take': 1,
#  'talk': 2,
#  'taxes,': 1,
#  'technologies': 1,
#  'tell': 1,
#  'tells': 1,
#  'tens': 1,
#  'terrorism,': 1,
#  'thank': 2,
#  'that': 8,
#  'the': 70,
#  'their': 11,
#  'themselves.': 1,
#  'then': 1,
#  'there': 3,
#  'these': 3,
#  'they': 5,
#  'think': 1,
#  'this': 9,
#  'this,': 1,
#  'thought': 1,
#  'thrive': 1,
#  'through': 1,
#  'throughout': 1,
#  'time': 2,
#  'to': 37,
#  'today': 4,
#  'today’s': 1,
#  'together': 1,
#  'together,': 3,
#  'tombstones': 1,
#  'tomorrow.': 1,
#  'too': 3,
#  'total': 1,
#  'totally': 1,
#  'trade,': 1,
#  'transfer': 1,
#  'transferring': 2,
#  'transition.': 1,
#  'trapped': 1,
#  'trillions': 1,
#  'triumphs': 1,
#  'triumphs;': 1,
#  'truly': 1,
#  'tunnels,': 1,
#  'two': 1,
#  'understand': 1,
#  'understanding': 1,
#  'unite': 1,
#  'united': 2,
#  'united,': 1,
#  'unity.”': 1,
#  'unlock': 1,
#  'unrealized': 1,
#  'unstoppable.': 1,
#  'up': 1,
#  'upon': 1,
#  'urban': 1,
#  'us': 1,
#  'us,': 1,
#  'very': 2,
#  'victories': 1,
#  'victories;': 1,
#  'vision': 1,
#  'voice,': 1,
#  'want': 1,
#  'was': 1,
#  'washington': 1,
#  'washington,': 1,
#  'watching': 1,
#  'way': 1,
#  'way.': 1,
#  'we': 45,
#  'we,': 1,
#  'wealth': 1,
#  'wealth,': 1,
#  'wealth.': 2,
#  'wealthy': 1,
#  'welfare': 1,
#  'we’ve': 3,
#  'what': 1,
#  'when': 3,
#  'whether': 3,
#  'which': 4,
#  'while': 6,
#  'white,': 1,
#  'who': 1,
#  'will': 40,
#  'windswept': 1,
#  'winning': 2,
#  'wisdom': 1,
#  'with': 8,
#  'women': 2,
#  'wonderful': 1,
#  'words:': 1,
#  'work': 1,
#  'workers': 2,
#  'world': 4,
#  'world.': 1,
#  'world:': 1,
#  'years': 1,
#  'years,': 1,
#  'yes,': 1,
#  'you': 7,
#  'you,': 3,
#  'you.': 2,
#  'young': 1,
#  'your': 11,
#  '–': 12,
#  '“how': 1}

# %%
# ?sorted

# %%
dic.items() #可遍歷的組合
# Out:
# dict_items([('administration', 1), ('cities;', 1), ('special', 1), ('middle', 1), ('office', 1), ('president', 5), ('come.', 1), ('debate', 1), ('unlock', 1), ('left,', 1), ('longer.', 1), ('highways,', 1), ('allowing', 1), ('triumphs;', 1), ('god.', 1), ('gathered', 1), ('heal', 1), ('decades,', 1), ('our', 48), ('technologies', 1), ('hall', 1), ('now', 3), ('flourished', 1), ('fellow', 1), ('way.', 1), ('openly,', 1), ('bible', 1), ('space,', 1), ('action', 1), ('want', 1), ('live', 1), ('world:', 1), ('stand', 1), ('carnage', 1), ('borne', 1), ('fail.', 1), ('life', 2), ('courage', 1), ('scattered', 1), ('but', 13), ('dreams.', 1), ('tunnels,', 1), ('country,', 1), ('welfare', 1), ('its', 3), ('capital', 1), ('understanding', 1), ('free', 1), ('plains', 1), ('wealthy', 1), ('complaining', 1), ('drugs', 1), ('far,', 1), ('importantly,', 1), ('factories', 3), ('do', 3), ('almighty', 1), ('mountain,', 1), ('made', 2), ('protect', 1), ('truly', 1), ('even', 2), ('night', 1), ('obama,', 1), ('through', 1), ('day', 2), ('bleed', 1), ('reaped', 1), ('affairs,', 1), ('is', 21), ('heard', 1), ('refusing', 1), ('throughout', 1), ('never', 5), ('changes', 1), ('us', 1), ('immigration,', 1), ('country.', 2), ('friendship', 1), ('effort', 1), ('themselves.', 1), ('share', 2), ('bless', 2), ('you.', 2), ('bedrock', 1), ('ocean', 1), ('expense', 1), ('victories', 1), ('spirit', 1), ('each', 1), ('roberts,', 1), ('pride', 1), ('controlled', 1), ('public.', 1), ('now,', 1), ('anything', 1), ('cash,', 1), ('let', 3), ('heart', 3), ('alliances', 1), ('they', 5), ('orderly', 1), ('out', 1), ('simple', 1), ('dollars', 1), ('my', 1), ('reinforce', 1), ('city,', 1), ('we,', 1), ('inner', 1), ('fallen', 1), ('matters', 1), ('against', 1), ('while', 6), ('too', 3), ('guide', 1), ('job', 1), ('national', 2), ('part', 1), ('freedoms,', 1), ('roads,', 1), ('disrepair', 1), ('stealing', 1), ('neighborhoods', 1), ('define', 1), ('strength,', 1), ('america.', 3), ('american', 11), ('oath', 2), ('borders', 2), ('past.', 1), ('just', 1), ('borders.', 1), ('long,', 1), ('in', 14), ('day.', 1), ('students', 1), ('hire', 1), ('another', 1), ('build', 1), ('talk', 2), ('magnificent.', 1), ('crime', 1), ('body', 1), ('seek', 2), ('sprawl', 1), ('world.', 1), ('whether', 3), ('seen', 1), ('dream', 1), ('carter,', 1), ('power.', 1), ('transfer', 1), ('lady', 1), ('have', 5), ('struggling', 1), ('poverty', 1), ('rich', 1), ('about', 2), ('we’ve', 3), ('2017,', 1), ('look', 1), ('and,', 2), ('before.', 2), ('future.', 1), ('carry', 1), ('grateful', 1), ('match', 1), ('good', 2), ('railways', 1), ('d.c.', 1), ('merely', 1), ('shuttered', 1), ('industry;', 1), ('what', 1), ('center', 1), ('time', 2), ('on,', 1), ('hands', 1), ('words:', 1), ('transferring', 2), ('behind.', 1), ('workers', 2), ('it', 9), ('decision', 1), ('stops', 2), ('i', 3), ('thank', 2), ('interests', 1), ('capital,', 2), ('trade,', 1), ('decree', 1), ('years', 1), ('giving', 1), ('rather', 1), ('rusted-out', 1), ('upon', 1), ('countries', 3), ('schools', 1), ('meaning.', 1), ('tells', 1), ('pleasant', 1), ('rebuilding', 1), ('you,', 3), ('as', 5), ('millions', 3), ('jobs.', 2), ('no', 6), ('ever', 1), ('flush', 1), ('thrive', 1), ('unity.”', 1), ('finally,', 1), ('prejudice.', 1), ('goodwill', 1), ('eradicate', 1), ('citizens.', 1), ('crucial', 1), ('restore', 1), ('was', 1), ('form', 1), ('enriched', 1), ('these', 3), ('born', 1), ('ceremony,', 1), ('wealth,', 1), ('steps', 1), ('government', 2), ('will', 40), ('enforcement', 1), ('system,', 1), ('miseries', 1), ('knowledge;', 1), ('wisdom', 1), ('celebrated', 1), ('shores,', 1), ('benefit', 1), ('hour', 1), ('righteous', 1), ('hopes,', 1), ('allegiance', 2), ('god’s', 1), ('landscape', 1), ('spent', 1), ('into', 1), ('old', 2), ('open', 1), ('gangs', 1), ('only', 2), ('another,', 1), ('accept', 1), ('like', 2), ('disagreements', 1), ('patriotism,', 1), ('to', 37), ('example', 1), ('sights,', 1), ('forgotten', 2), ('across', 5), ('america', 10), ...

# %%
import operator
swd=sorted(dic.items(), key=operator.itemgetter(1), reverse=True )
#dic.items() 可遍歷的組合
#key=operator.itemgetter(1)    1表按照頻率排序  reverse表從高到低

# %%
swd
# Out:
# [('and', 72),
#  ('the', 70),
#  ('our', 48),
#  ('of', 48),
#  ('we', 45),
#  ('will', 40),
#  ('to', 37),
#  ('is', 21),
#  ('for', 16),
#  ('a', 15),
#  ('in', 14),
#  ('are', 14),
#  ('but', 13),
#  ('all', 12),
#  ('be', 12),
#  ('–', 12),
#  ('american', 11),
#  ('from', 11),
#  ('their', 11),
#  ('your', 11),
#  ('america', 10),
#  ('not', 10),
#  ('it', 9),
#  ('this', 9),
#  ('with', 8),
#  ('that', 8),
#  ('again.', 8),
#  ('you', 7),
#  ('one', 7),
#  ('every', 7),
#  ('while', 6),
#  ('no', 6),
#  ('country', 6),
#  ('has', 6),
#  ('new', 6),
#  ('back', 6),
#  ('on', 6),
#  ('same', 6),
#  ('great', 6),
#  ('people', 6),
#  ('by', 6),
#  ('president', 5),
#  ('never', 5),
#  ('they', 5),
#  ('have', 5),
#  ('as', 5),
#  ('across', 5),
#  ('at', 5),
#  ('make', 5),
#  ('right', 5),
#  ('other', 4),
#  ('which', 4),
#  ('bring', 4),
#  ('america,', 4),
#  ('nation', 4),
#  ('world', 4),
#  ('today', 4),
#  ('or', 4),
#  ('been', 4),
#  ('everyone', 4),
#  ('now', 3),
#  ('its', 3),
#  ('factories', 3),
#  ('do', 3),
#  ('let', 3),
#  ('heart', 3),
#  ('too', 3),
#  ('america.', 3),
#  ('whether', 3),
#  ('we’ve', 3),
#  ('i', 3),
#  ('countries', 3),
#  ('you,', 3),
#  ('millions', 3),
#  ('these', 3),
#  ('here', 3),
#  ('protected', 3),
#  ('must', 3),
#  ('people.', 3),
#  ('an', 3),
#  ('foreign', 3),
#  ('together,', 3),
#  ('there', 3),
#  ('when', 3),
#  ('so', 3),
#  ('many', 3),
#  ('nation’s', 3),
#  ('life', 2),
#  ('made', 2),
#  ('even', 2),
#  ('day', 2),
#  ('country.', 2),
#  ('share', 2),
#  ('bless', 2),
#  ('you.', 2),
#  ('national', 2),
#  ('oath', 2),
#  ('borders', 2),
#  ('talk', 2),
#  ('seek', 2),
#  ('about', 2),
#  ('and,', 2),
#  ('before.', 2),
#  ('good', 2),
#  ('time', 2),
#  ('transferring', 2),
#  ('workers', 2),
#  ('stops', 2),
#  ('thank', 2),
#  ('capital,', 2),
#  ('jobs.', 2),
#  ('government', 2),
#  ('allegiance', 2),
#  ('old', 2),
#  ('only', 2),
#  ('like', 2),
#  ('forgotten', 2),
#  ('dreams,', 2),
#  ('states', 2),
#  ('very', 2),
#  ('party', 2),
#  ('done.', 2),
#  ('small', 2),
#  ('power', 2),
#  ('loyalty', 2),
#  ('movement', 2),
#  ('moment', 2),
#  ('jobs', 2),
#  ('wealth.', 2),
#  ('safe', 2),
#  ('destiny.', 2),
#  ('men', 2),
#  ('face', 2),
#  ('citizens', 2),
#  ('obama', 2),
#  ('women', 2),
#  ('americans,', 2),
#  ('get', 2),
#  ('first.', 2),
#  ('glorious', 2),
#  ('left', 2),
#  ('breath', 2),
#  ('because', 2),
#  ('always', 2),
#  ('nations', 2),
#  ('now.', 2),
#  ('politicians', 2),
#  ('united', 2),
#  ('fight', 2),
#  ('land.', 2),
#  ('god', 2),
#  ('winning', 2),
#  ('belongs', 2),
#  ('administration', 1),
#  ('cities;', 1),
#  ('special', 1),
#  ('middle', 1),
#  ('office', 1),
#  ('come.', 1),
#  ('debate', 1),
#  ('unlock', 1),
#  ('left,', 1),
#  ('longer.', 1),
#  ('highways,', 1),
#  ('allowing', 1),
#  ('triumphs;', 1),
#  ('god.', 1),
#  ('gathered', 1),
#  ('heal', 1),
#  ('decades,', 1),
#  ('technologies', 1),
#  ('hall', 1),
#  ('flourished', 1),
#  ('fellow', 1),
#  ('way.', 1),
#  ('openly,', 1),
#  ('bible', 1),
#  ('space,', 1),
#  ('action', 1),
#  ('want', 1),
#  ('live', 1),
#  ('world:', 1),
#  ('stand', 1),
#  ('carnage', 1),
#  ('borne', 1),
#  ('fail.', 1),
#  ('courage', 1),
#  ('scattered', 1),
#  ('dreams.', 1),
#  ('tunnels,', 1),
#  ('country,', 1),
#  ('welfare', 1),
#  ('capital', 1),
#  ('understanding', 1),
#  ('free', 1),
#  ('plains', 1),
#  ('wealthy', 1),
#  ('complaining', 1),
#  ('drugs', 1),
#  ('far,', 1),
#  ('importantly,', 1),
#  ('almighty', 1),
#  ('mountain,', 1),
#  ('protect', 1),
#  ('truly', 1),
#  ('night', 1),
#  ('obama,', 1),
#  ('through', 1),
#  ('bleed', 1),
#  ('reaped', 1),
#  ('affairs,', 1),
#  ('heard', 1),
#  ('refusing', 1),
#  ('throughout', 1),
#  ('changes', 1),
#  ('us', 1),
#  ('immigration,', 1),
#  ('friendship', 1),
#  ('effort', 1),
#  ('themselves.', 1),
#  ('bedrock', 1),
#  ('ocean', 1),
#  ('expense', 1),
#  ('victories', 1),
#  ('spirit', 1),
#  ('each', 1),
#  ('roberts,', 1),
#  ('pride', 1),
#  ('controlled', 1),
#  ('public.', 1),
#  ('now,', 1),
#  ('anything', 1),
#  ('cash,', 1),
#  ('alliances', 1),
#  ('orderly', 1),
#  ('out', 1),
#  ('simple', 1),
#  ('dollars', 1),
#  ('my', 1),
#  ('reinforce', 1),
#  ('city,', 1),
#  ('we,', 1),
#  ('inner', 1),
#  ('fallen', 1),
#  ('matters', 1),
#  ('against', 1),
#  ('guide', 1),
#  ('job', 1),
#  ('part', 1),
#  ('freedoms,', 1),
#  ('roads,', 1),
#  ('disrepair', 1),
#  ('stealing', 1),
#  ('neighborhoods', 1),
#  ('define', 1),
#  ('strength,', 1),
#  ('past.', 1),
#  ('just', 1),
#  ('borders.', 1),
#  ('long,', 1),
#  ('day.', 1),
#  ('students', 1),
#  ('hire', 1),
#  ('another', 1),
#  ('build', 1),
#  ('magnificent.', 1),
#  ('crime', 1),
#  ('body', 1),
#  ('sprawl', 1),
#  ('world.', 1),
#  ('seen', 1),
#  ('dream', 1),
#  ('carter,', 1),
#  ('power.', 1),
#  ('transfer', 1),
#  ('lady', 1),
#  ('struggling', 1),
#  ('poverty', 1),
#  ('rich', 1),
#  ('2017,', 1),
#  ('look', 1),
#  ('future.', 1),
#  ('carry', 1),
#  ('grateful', 1),
#  ('match', 1),
#  ('railways', 1),
#  ('d.c.', 1),
#  ('merely', 1),
#  ('shuttered', 1),
#  ('industry;', 1),
#  ('what', 1),
#  ('center', 1),
#  ('on,', 1),
#  ('hands', 1),
#  ('words:', 1),
#  ('behind.', 1),
#  ('decision', 1),
#  ('interests', 1),
#  ('trade,', 1),
#  ('decree', 1),
#  ('years', 1),
#  ('giving', 1),
#  ('rather', 1),
#  ('rusted-out', 1),
#  ('upon', 1),
#  ('schools', 1),
#  ('meaning.', 1),
#  ('tells', 1),
#  ('pleasant', 1),
#  ('rebuilding', 1),
#  ('ever', 1),
#  ('flush', 1),
#  ('thrive', 1),
#  ('unity.”', 1),
#  ('finally,', 1),
#  ('prejudice.', 1),
#  ('goodwill', 1),
#  ('eradicate', 1),
#  ('citizens.', 1),
#  ('crucial', 1),
#  ('restore', 1),
#  ('was', 1),
#  ('form', 1),
#  ('enriched', 1),
#  ('born', 1),
#  ('ceremony,', 1),
#  ('wealth,', 1),
#  ('steps', 1),
#  ('enforcement', 1),
#  ('system,', 1),
#  ('miseries', 1),
#  ('knowledge;', 1),
#  ('wisdom', 1),
#  ('celebrated', 1),
#  ('shores,', 1),
#  ('benefit', 1),
#  ('hour', 1),
#  ('righteous', 1),
#  ('hopes,', 1),
#  ('god’s', 1),
#  ('landscape', 1),
#  ('spent', 1),
#  ('into', 1),
#  ('open', 1),
#  ('gangs', 1),
#  ('another,', 1),
#  ('accept', 1),
#  ('disagreements', 1),
#  ('patriotism,', 1),
#  ('example', 1),
#  ('sights,', 1),
#  ('prospered', 1),
#  ('large,', 1),
#  ('longer', 1),
#  ('cannot', 1),
#  ('who', 1),
#  ('wealth', 1),
#  ('pain', 1),
#  ('energies,', 1),
#  ('success', 1),
#  ('prosperity', 1),
#  ('gracious', 1),
#  ('taxes,', 1),
#  ('child', 1),
#  ('redistributed', 1),
#  ('buy', 1),
#  ('confidence', 1),
#  ('armies', 1),
#  ('ocean,', 1),
#  ('lift', 1),
#  ('making', 1),
#  ('dreams;', 1),
#  ('rebuild', 1),
#  ('goodness', 1),
#  ('closed.', 1),
#  ('white,', 1),
#  ('washington', 1),
#  ('two', 1),
#  ('mothers', 1),
#  ('windswept', 1),
#  ('triumphs', 1),
#  ('challenge', 1),
#  ('families,', 1),
#  ('moment:', 1),
#  ('american.', 1),
#  ('patriots,', 1),
#  ('most', 1),
#  ('robbed', 1),
#  ('rewards', 1),
#  ('speak', 1),
#  ('yes,', 1),
#  ('solidarity.', 1),
#  ('itself,', 1),
#  ('completely', 1),
#  ('issuing', 1),
#  ('wonderful', 1),
#  ('trapped', 1),
#  ('exists', 1),
#  ('depletion', 1),
#  ('earth.', 1),
#  ('ignored', 1),
#  ('off', 1),
#  ('totally', 1),
#  ('urban', 1),
#  ('deprived', 1),
#  ('prepared', 1),
#  ('souls,', 1),
#  ('protected.', 1),
#  ('total', 1),
#  ('protected,', 1),
#  ('listening', 1),
#  ('thought', 1),
#  ('fill', 1),
#  ('assembled', 1),
#  ('however,', 1),
#  ('become', 1),
#  ('home,', 1),
#  ('aid', 1),
#  ('unite', 1),
#  ('shine', 1),
#  ('black', 1),
#  ('red', 1),
#  ('salute', 1),
#  ('up', 1),
#  ('dreams', 1),
#  ('again,', 1),
#  ('tombstones', 1),
#  ('promise', 1),
#  ('hardships.', 1),
#  ('families.', 1),
#  ('own', 1),
#  ('starting', 1),
#  ('other.', 1),
#  ('united,', 1),
#  ('heart,', 1),
#  ('lead', 1),
#  ('proud', 1),
#  ('harness', 1),
#  ('became', 1),
#  ('americans.', 1),
#  ('along', 1),
#  ('demands', 1),
#  ('love', 1),
#  ('birth', 1),
#  ('radical', 1),
#  ('living', 1),
#  ('justice', 1),
#  ('rulers', 1),
#  ('america’s', 1),
#  ('little', 1),
#  ('michelle', 1),
#  ('“how', 1),
#  ('establishment', 1),
#  ('chief', 1),
#  ('strong', 1),
#  ('civilized', 1),
#  ('citizens,', 1),
#  ('celebration.', 1),
#  ('ready', 1),
#  ('bigger.', 1),
#  ('cost.', 1),
#  ('joined', 1),
#  ('washington,', 1),
#  ('defended', 1),
#  ('this,', 1),
#  ('earth', 1),
#  ('military;', 1),
#  ('looking', 1),
#  ('big', 1),
#  ('infrastructure', 1),
#  ('anyone', 1),
#  ('understand', 1),
#  ('nation;', 1),
#  ('going', 1),
#  ('reasonable', 1),
#  ('young', 1),
#  ('law', 1),
#  ('over', 1),
#  ('politics', 1),
#  ('subsidized', 1),
#  ('anyone,', 1),
#  ('action.', 1),
#  ('it’s', 1),
#  ('divisions.', 1),
#  ('peaceful', 1),
#  ('hear', 1),
#  ('infused', 1),
#  ('way', 1),
#  ('brown', 1),
#  ('minds', 1),
#  ('govern', 1),
#  ('flag.', 1),
#  ('tell', 1),
#  ('lives', 1),
#  ('soldiers', 1),
#  ('first', 1),
#  ('four', 1),
#  ('forget:', 1),
#  ('it.', 1),
#  ('did', 1),
#  ('products,', 1),
#  ('start', 1),
#  ('arrives', 1),
#  ('determine', 1),
#  ('vision', 1),
#  ('homes', 1),
#  ('pursue', 1),
#  ('unstoppable.', 1),
#  ('remember', 1),
#  ('years,', 1),
#  ('empty', 1),
#  ('watching', 1),
#  ('likes', 1),
#  ('disappeared', 1),
#  ('creator.', 1),
#  ('government,', 1),
#  ('controls', 1),
#  ('january', 1),
#  ('room', 1),
#  ('decay.', 1),
#  ('us,', 1),
#  ('bridges,', 1),
#  ('over.', 1),
#  ('disease,', 1),
#  ('fear', 1),
#  ('tomorrow.', 1),
#  ('enjoy', 1),
#  ('americans', 1),
#  ('course', 1),
#  ('class', 1),
#  ('delivery', 1),
#  ('never,', 1),
#  ('airports,', 1),
#  ('work', 1),
#  ('serve', 1),
#  ('terrorism,', 1),
#  ('came', 1),
#  ('one,', 1),
#  ('mountain', 1),
#  ('together', 1),
#  ('children', 1),
#  ('blood', 1),
#  ('forward,', 1),
#  ('reality', 1),
#  ('forever', 1),
#  ('military', 1),
#  ('voice,', 1),
#  ('prosper', 1),
#  ('islamic', 1),
#  ('stir', 1),
#  ('ripped', 1),
#  ('remembered', 1),
#  ('gather', 1),
#  ('stolen', 1),
#  ('striving.', 1),
#  ('celebrate', 1),
#  ('down.', 1),
#  ('millennium,', 1),
#  ('families', 1),
#  ('trillions', 1),
#  ('ones', 1),
#  ('constantly', 1),
#  ('detroit', 1),
#  ('impose', 1),
#  ('clinton,', 1),
#  ('children,', 1),
#  ('follow.', 1),
#  ('exists:', 1),
#  ('long', 1),
#  ('unrealized', 1),
#  ('can', 1),
#  ('own;', 1),
#  ('think', 1),
#  ('then', 1),
#  ('sad', 1),
#  ('nebraska,', 1),
#  ('protection', 1),
#  ('bush,', 1),
#  ('mysteries', 1),
#  ('different', 1),
#  ('leaves', 1),
#  ('20th', 1),
#  ('today’s', 1),
#  ('transition.', 1),
#  ('potential.', 1),
#  ('pain.', 1),
#  ('industry', 1),
#  ('strength.', 1),
#  ('should', 1),
#  ('group', 1),
#  ('sky,', 1),
#  ('education', 1),
#  ('nation.', 1),
#  ('companies,', 1),
#  ('victories;', 1),
#  ('here,', 1),
#  ('much', 1),
#  ('tens', 1),
#  ('city', 1),
#  ('labor.', 1),
#  ('success.', 1),
#  ('take', 1),
#  ('beautiful', 1),
#  ('entire', 1),
#  ('conviction:', 1),
#  ('put', 1),
#  ('rules:', 1),
#  ('horizon.', 1),
#  ('ravages', 1),
#  ('near', 1),
#  ('destroying', 1),
#  ('follow', 1),
#  ('doing', 1),
#  ('honestly,', 1),
#  ('historic', 1),
#  ('rediscover', 1),
#  ('overseas', 1),
#  ('defend', 1),
#  ('power,', 1),
#  ('industries', 1),
#  ('challenges.', 1),
#  ('confront', 1)]

# %%
from nltk.corpus import stopwords
stop_words=stopwords.words('English')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
#remove stop_words
for k ,v in swd:
    if k not in stop_words:
        print(k,v)
# Out:
# – 12
# american 11
# america 10
# again. 8
# one 7
# every 7
# country 6
# new 6
# back 6
# great 6
# people 6
# president 5
# never 5
# across 5
# make 5
# right 5
# bring 4
# america, 4
# nation 4
# world 4
# today 4
# everyone 4
# factories 3
# let 3
# heart 3
# america. 3
# whether 3
# we’ve 3
# countries 3
# you, 3
# millions 3
# protected 3
# must 3
# people. 3
# foreign 3
# together, 3
# many 3
# nation’s 3
# life 2
# made 2
# even 2
# day 2
# country. 2
# share 2
# bless 2
# you. 2
# national 2
# oath 2
# borders 2
# talk 2
# seek 2
# and, 2
# before. 2
# good 2
# time 2
# transferring 2
# workers 2
# stops 2
# thank 2
# capital, 2
# jobs. 2
# government 2
# allegiance 2
# old 2
# like 2
# forgotten 2
# dreams, 2
# states 2
# party 2
# done. 2
# small 2
# power 2
# loyalty 2
# movement 2
# moment 2
# jobs 2
# wealth. 2
# safe 2
# destiny. 2
# men 2
# face 2
# citizens 2
# obama 2
# women 2
# americans, 2
# get 2
# first. 2
# glorious 2
# left 2
# breath 2
# always 2
# nations 2
# now. 2
# politicians 2
# united 2
# fight 2
# land. 2
# god 2
# winning 2
# belongs 2
# administration 1
# cities; 1
# special 1
# middle 1
# office 1
# come. 1
# debate 1
# unlock 1
# left, 1
# longer. 1
# highways, 1
# allowing 1
# triumphs; 1
# god. 1
# gathered 1
# heal 1
# decades, 1
# technologies 1
# hall 1
# flourished 1
# fellow 1
# way. 1
# openly, 1
# bible 1
# space, 1
# action 1
# want 1
# live 1
# world: 1
# stand 1
# carnage 1
# borne 1
# fail. 1
# courage 1
# scattered 1
# dreams. 1
# tunnels, 1
# country, 1
# welfare 1
# capital 1
# understanding 1
# free 1
# plains 1
# wealthy 1
# complaining 1
# drugs 1
# far, 1
# importantly, 1
# almighty 1
# mountain, 1
# protect 1
# truly 1
# night 1
# obama, 1
# bleed 1
# reaped 1
# affairs, 1
# heard 1
# refusing 1
# throughout 1
# changes 1
# us 1
# immigration, 1
# friendship 1
# effort 1
# themselves. 1
# bedrock 1
# ocean 1
# expense 1
# victories 1
# spirit 1
# roberts, 1
# pride 1
# controlled 1
# public. 1
# now, 1
# anything 1
# cash, 1
# alliances 1
# orderly 1
# simple 1
# dollars 1
# reinforce 1
# city, 1
# we, 1
# inner 1
# fallen 1
# matters 1
# guide 1
# job 1
# part 1
# freedoms, 1
# roads, 1
# disrepair 1
# stealing 1
# neighborhoods 1
# define 1
# strength, 1
# past. 1
# borders. 1
# long, 1
# day. 1
# students 1
# hire 1
# another 1
# build 1
# magnificent. 1
# crime 1
# body 1
# sprawl 1
# world. 1
# seen 1
# dream 1
# carter, 1
# power. 1
# transfer 1
# lady 1
# struggling 1
# poverty 1
# rich 1
# 2017, 1
# look 1
# future. 1
# carry 1
# grateful 1
# match 1
# railways 1
# d.c. 1
# merely 1
# shuttered 1
# industry; 1
# center 1
# on, 1
# hands 1
# words: 1
# behind. 1
# decision 1
# interests 1
# trade, 1
# decree 1
# years 1
# giving 1
# rather 1
# rusted-out 1
# upon 1
# schools 1
# meaning. 1
# tells 1
# pleasant 1
# rebuilding 1
# ever 1
# flush 1
# thrive 1
# unity.” 1
# finally, 1
# prejudice. 1
# goodwill 1
# eradicate 1
# citizens. 1
# crucial 1
# restore 1
# form 1
# enriched 1
# born 1
# ceremony, 1
# wealth, 1
# steps 1
# enforcement 1
# system, 1
# miseries 1
# knowledge; 1
# wisdom 1
# celebrated 1
# shores, 1
# benefit 1
# hour 1
# righteous 1
# hopes, 1
# god’s 1
# landscape 1
# spent 1
# open 1
# gangs 1
# another, 1
# accept 1
# disagreements 1
# patriotism, 1
# example 1
# sights, 1
# prospered 1
# large, 1
# longer 1
# cannot 1
# wealth 1
# pain 1
# energies, 1
# success 1
# prosperity 1
# gracious 1
# taxes, 1
# child 1
# redistributed 1
# buy 1
# confidence 1
# armies 1
# ocean, 1
# lift 1
# making 1
# dreams; 1
# rebuild 1
# goodness 1
# closed. 1
# white, 1
# washington 1
# two 1
# mothers 1
# windswept 1
# triumphs 1
# challenge 1
# families, 1
# moment: 1
# american. 1
# patriots, 1
# robbed 1
# rewards 1
# speak 1
# yes, 1
# solidarity. 1
# itself, 1
# completely 1
# issuing 1
# wonderful 1
# trapped 1
# exists 1
# depletion 1
# earth. 1
# ignored 1
# totally 1
# urban 1
# deprived 1
# prepared 1
# souls, 1
# protected. 1
# total 1
# protected, 1
# listening 1
# thought 1
# fill 1
# assembled 1
# however, 1
# become 1
# home, 1
# aid 1
# unite 1
# shine 1
# black 1
# red 1
# salute 1
# dreams 1
# again, 1
# tombstones 1
# promise 1
# hardships. 1
# families. 1
# starting 1
# other. 1
# united, 1
# heart, 1
# lead 1
# proud 1
# harness 1
# became 1
# americans. 1
# along 1
# demands 1
# love 1
# birth 1
# radical 1
# living 1
# justice 1
# rulers 1
# america’s 1
# little 1
# michelle 1
# “how 1
# establishment 1
# chief 1
# strong 1
# civilized 1
# citizens, 1
# celebration. 1
# ready 1
# bigger. 1
# cost. 1
# joined 1
# washington, 1
# defended 1
# this, 1
# earth 1
# military; 1
# looking 1
# big 1
# infrastructure 1
# anyone 1
# understand 1
# nation; 1
# going 1
# reasonable 1
# young 1
# law 1
# politics 1
# subsidized 1
# anyone, 1
# action. 1
# it’s 1
# divisions. 1
# peaceful 1
# hear 1
# infused 1
# way 1
# brown 1
# minds 1
# govern 1
# flag. 1
# tell 1
# lives 1
# soldiers 1
# first 1
# four 1
# forget: 1
# it. 1
# products, 1
# start 1
# arrives 1
# determine 1
# vision 1
# homes 1
# pursue 1
# unstoppable. 1
# remember 1
# years, 1
# empty 1
# watching 1
# likes 1
# disappeared 1
# creator. 1
# government, 1
# controls 1
# january 1
# room 1
# decay. 1
# us, 1
# bridges, 1
# over. 1
# disease, 1
# fear 1
# tomorrow. 1
# enjoy 1
# americans 1
# course 1
# class 1
# delivery 1
# never, 1
# airports, 1
# work 1
# serve 1
# terrorism, 1
# came 1
# one, 1
# mountain 1
# together 1
# children 1
# blood 1
# forward, 1
# reality 1
# forever 1
# military 1
# voice, 1
# prosper 1
# islamic 1
# stir 1
# ripped 1
# remembered 1
# gather 1
# stolen 1
# striving. 1
# celebrate 1
# down. 1
# millennium, 1
# families 1
# trillions 1
# ones 1
# constantly 1
# detroit 1
# impose 1
# clinton, 1
# children, 1
# follow. 1
# exists: 1
# long 1
# unrealized 1
# own; 1
# think 1
# sad 1
# nebraska, 1
# protection 1
# bush, 1
# mysteries 1
# different 1
# leaves 1
# 20th 1
# today’s 1
# transition. 1
# potential. 1
# pain. 1
# industry 1
# strength. 1
# group 1
# sky, 1
# education 1
# nation. 1
# companies, 1
# victories; 1
# here, 1
# much 1
# tens 1
# city 1
# labor. 1
# success. 1
# take 1
# beautiful 1
# entire 1
# conviction: 1
# put 1
# rules: 1
# horizon. 1
# ravages 1
# near 1
# destroying 1
# follow 1
# honestly, 1
# historic 1
# rediscover 1
# overseas 1
# defend 1
# power, 1
# industries 1
# challenges. 1
# confront 1

# %% [markdown]
# ## Word Count (**Version2)

# %%
from collections import Counter
c=Counter(speech)

# %%
c
# Out:
# Counter({'2017,': 1,
#          '20th': 1,
#          'a': 15,
#          'about': 2,
#          'accept': 1,
#          'across': 5,
#          'action': 1,
#          'action.': 1,
#          'administration': 1,
#          'affairs,': 1,
#          'again,': 1,
#          'again.': 8,
#          'against': 1,
#          'aid': 1,
#          'airports,': 1,
#          'all': 12,
#          'allegiance': 2,
#          'alliances': 1,
#          'allowing': 1,
#          'almighty': 1,
#          'along': 1,
#          'always': 2,
#          'america': 10,
#          'america,': 4,
#          'america.': 3,
#          'american': 11,
#          'american.': 1,
#          'americans': 1,
#          'americans,': 2,
#          'americans.': 1,
#          'america’s': 1,
#          'an': 3,
#          'and': 72,
#          'and,': 2,
#          'another': 1,
#          'another,': 1,
#          'anyone': 1,
#          'anyone,': 1,
#          'anything': 1,
#          'are': 14,
#          'armies': 1,
#          'arrives': 1,
#          'as': 5,
#          'assembled': 1,
#          'at': 5,
#          'back': 6,
#          'be': 12,
#          'beautiful': 1,
#          'became': 1,
#          'because': 2,
#          'become': 1,
#          'bedrock': 1,
#          'been': 4,
#          'before.': 2,
#          'behind.': 1,
#          'belongs': 2,
#          'benefit': 1,
#          'bible': 1,
#          'big': 1,
#          'bigger.': 1,
#          'birth': 1,
#          'black': 1,
#          'bleed': 1,
#          'bless': 2,
#          'blood': 1,
#          'body': 1,
#          'borders': 2,
#          'borders.': 1,
#          'born': 1,
#          'borne': 1,
#          'breath': 2,
#          'bridges,': 1,
#          'bring': 4,
#          'brown': 1,
#          'build': 1,
#          'bush,': 1,
#          'but': 13,
#          'buy': 1,
#          'by': 6,
#          'came': 1,
#          'can': 1,
#          'cannot': 1,
#          'capital': 1,
#          'capital,': 2,
#          'carnage': 1,
#          'carry': 1,
#          'carter,': 1,
#          'cash,': 1,
#          'celebrate': 1,
#          'celebrated': 1,
#          'celebration.': 1,
#          'center': 1,
#          'ceremony,': 1,
#          'challenge': 1,
#          'challenges.': 1,
#          'changes': 1,
#          'chief': 1,
#          'child': 1,
#          'children': 1,
#          'children,': 1,
#          'cities;': 1,
#          'citizens': 2,
#          'citizens,': 1,
#          'citizens.': 1,
#          'city': 1,
#          'city,': 1,
#          'civilized': 1,
#          'class': 1,
#          'clinton,': 1,
#          'closed.': 1,
#          'come.': 1,
#          'companies,': 1,
#          'complaining': 1,
#          'completely': 1,
#          'confidence': 1,
#          'confront': 1,
#          'constantly': 1,
#          'controlled': 1,
#          'controls': 1,
#          'conviction:': 1,
#          'cost.': 1,
#          'countries': 3,
#          'country': 6,
#          'country,': 1,
#          'country.': 2,
#          'courage': 1,
#          'course': 1,
#          'creator.': 1,
#          'crime': 1,
#          'crucial': 1,
#          'd.c.': 1,
#          'day': 2,
#          'day.': 1,
#          'debate': 1,
#          'decades,': 1,
#          'decay.': 1,
#          'decision': 1,
#          'decree': 1,
#          'defend': 1,
#          'defended': 1,
#          'define': 1,
#          'delivery': 1,
#          'demands': 1,
#          'depletion': 1,
#          'deprived': 1,
#          'destiny.': 2,
#          'destroying': 1,
#          'determine': 1,
#          'detroit': 1,
#          'did': 1,
#          'different': 1,
#          'disagreements': 1,
#          'disappeared': 1,
#          'disease,': 1,
#          'disrepair': 1,
#          'divisions.': 1,
#          'do': 3,
#          'doing': 1,
#          'dollars': 1,
#          'done.': 2,
#          'down.': 1,
#          'dream': 1,
#          'dreams': 1,
#          'dreams,': 2,
#          'dreams.': 1,
#          'dreams;': 1,
#          'drugs': 1,
#          'each': 1,
#          'earth': 1,
#          'earth.': 1,
#          'education': 1,
#          'effort': 1,
#          'empty': 1,
#          'energies,': 1,
#          'enforcement': 1,
#          'enjoy': 1,
#          'enriched': 1,
#          'entire': 1,
#          'eradicate': 1,
#          'establishment': 1,
#          'even': 2,
#          'ever': 1,
#          'every': 7,
#          'everyone': 4,
#          'example': 1,
#          'exists': 1,
#          'exists:': 1,
#          'expense': 1,
#          'face': 2,
#          'factories': 3,
#          'fail.': 1,
#          'fallen': 1,
#          'families': 1,
#          'families,': 1,
#          'families.': 1,
#          'far,': 1,
#          'fear': 1,
#          'fellow': 1,
#          'fight': 2,
#          'fill': 1,
#          'finally,': 1,
#          'first': 1,
#          'first.': 2,
#          'flag.': 1,
#          'flourished': 1,
#          'flush': 1,
#          'follow': 1,
#          'follow.': 1,
#          'for': 16,
#          'foreign': 3,
#          'forever': 1,
#          'forget:': 1,
#          'forgotten': 2,
#          'form': 1,
#          'forward,': 1,
#          'four': 1,
#          'free': 1,
#          'freedoms,': 1,
#          'friendship': 1,
#          'from': 11,
#          'future.': 1,
#          'gangs': 1,
#          'gather': 1,
#          'gathered': 1,
#          'get': 2,
#          'giving': 1,
#          'glorious': 2,
#          'god': 2,
#          'god.': 1,
#          'god’s': 1,
#          'going': 1,
#          'good': 2,
#          'goodness': 1,
#          'goodwill': 1,
#          'govern': 1,
#          'government': 2,
#          'government,': 1,
#          'gracious': 1,
#          'grateful': 1,
#          'great': 6,
#          'group': 1,
#          'guide': 1,
#          'hall': 1,
#          'hands': 1,
#          'hardships.': 1,
#          'harness': 1,
#          'has': 6,
#          'have': 5,
#          'heal': 1,
#          'hear': 1,
#          'heard': 1,
#          'heart': 3,
#          'heart,': 1,
#          'here': 3,
#          'here,': 1,
#          'highways,': 1,
#          'hire': 1,
#          'historic': 1,
#          'home,': 1,
#          'homes': 1,
#          'honestly,': 1,
#          'hopes,': 1,
#          'horizon.': 1,
#          'hour': 1,
#          'however,': 1,
#          'i': 3,
#          'ignored': 1,
#          'immigration,': 1,
#          'importantly,': 1,
#          'impose': 1,
#          'in': 14,
#          'industries': 1,
#          'industry': 1,
#          'industry;': 1,
#          'infrastructure': 1,
#          'infused': 1,
#          'inner': 1,
#          'interests': 1,
#          'into': 1,
#          'is': 21,
#          'islamic': 1,
#          'issuing': 1,
#          'it': 9,
#          'it.': 1,
#          'its': 3,
#          'itself,': 1,
#          'it’s': 1,
#          'january': 1,
#          'job': 1,
#          'jobs': 2,
#          'jobs.': 2,
#          'joined': 1,
#          'just': 1,
#          'justice': 1,
#          'knowledge;': 1,
#          'labor.': 1,
#          'lady': 1,
#          'land.': 2,
#          'landscape': 1,
#          'large,': 1,
#          'law': 1,
#          'lead': 1,
#          'leaves': 1,
#          'left': 2,
#          'left,': 1,
#          'let': 3,
#          'life': 2,
#          'lift': 1,
#          'like': 2,
#          'likes': 1,
#          'listening': 1,
#          'little': 1,
#          'live': 1,
#          'lives': 1,
#          'living': 1,
#          'long': 1,
#          'long,': 1,
#          'longer': 1,
#          'longer.': 1,
#          'look': 1,
#          'looking': 1,
#          'love': 1,
#          'loyalty': 2,
#          'made': 2,
#          'magnificent.': 1,
#          'make': 5,
#          'making': 1,
#          'many': 3,
#          'match': 1,
#          'matters': 1,
#          'meaning.': 1,
#          'men': 2,
#          'merely': 1,
#          'michelle': 1,
#          'middle': 1,
#          'military': 1,
#          'military;': 1,
#          'millennium,': 1,
#          'millions': 3,
#          'minds': 1,
#          'miseries': 1,
#          'moment': 2,
#          'moment:': 1,
#          'most': 1,
#          'mothers': 1,
#          'mountain': 1,
#          'mountain,': 1,
#          'movement': 2,
#          'much': 1,
#          'must': 3,
#          'my': 1,
#          'mysteries': 1,
#          'nation': 4,
#          'nation.': 1,
#          'nation;': 1,
#          'national': 2,
#          'nations': 2,
#          'nation’s': 3,
#          'near': 1,
#          'nebraska,': 1,
#          'neighborhoods': 1,
#          'never': 5,
#          'never,': 1,
#          'new': 6,
#          'night': 1,
#          'no': 6,
#          'not': 10,
#          'now': 3,
#          'now,': 1,
#          'now.': 2,
#          'oath': 2,
#          'obama': 2,
#          'obama,': 1,
#          'ocean': 1,
#          'ocean,': 1,
#          'of': 48,
#          'off': 1,
#          'office': 1,
#          'old': 2,
#          'on': 6,
#          'on,': 1,
#          'one': 7,
#          'one,': 1,
#          'ones': 1,
#          'only': 2,
#          'open': 1,
#          'openly,': 1,
#          'or': 4,
#          'orderly': 1,
#          'other': 4,
#          'other.': 1,
#          'our': 48,
#          'out': 1,
#          'over': 1,
#          'over.': 1,
#          'overseas': 1,
#          'own': 1,
#          'own;': 1,
#          'pain': 1,
#          'pain.': 1,
#          'part': 1,
#          'party': 2,
#          'past.': 1,
#          'patriotism,': 1,
#          'patriots,': 1,
#          'peaceful': 1,
#          'people': 6,
#          'people.': 3,
#          'plains': 1,
#          'pleasant': 1,
#          'politicians': 2,
#          'politics': 1,
#          'potential.': 1,
#          'poverty': 1,
#          'power': 2,
#          'power,': 1,
#          'power.': 1,
#          'prejudice.': 1,
#          'prepared': 1,
#          'president': 5,
#          'pride': 1,
#          'products,': 1,
#          'promise': 1,
#          'prosper': 1,
#          'prospered': 1,
#          'prosperity': 1,
#          'protect': 1,
#          'protected': 3,
#          'protected,': 1,
#          'protected.': 1,
#          'protection': 1,
#          'proud': 1,
#          'public.': 1,
#          'pursue': 1,
#          'put': 1,
#          'radical': 1,
#          'railways': 1,
#          'rather': 1,
#          'ravages': 1,
#          'ready': 1,
#          'reality': 1,
#          'reaped': 1,
#          'reasonable': 1,
#          'rebuild': 1,
#          'rebuilding': 1,
#          'red': 1,
#          'rediscover': 1,
#          'redistributed': 1,
#          'refusing': 1,
#          'reinforce': 1,
#          'remember': 1,
#          'remembered': 1,
#          'restore': 1,
#          'rewards': 1,
#          'rich': 1,
#          'right': 5,
#          'righteous': 1,
#          'ripped': 1,
#          'roads,': 1,
#          'robbed': 1,
#          'roberts,': 1,
#          'room': 1,
#          'rulers': 1,
#          'rules:': 1,
#          'rusted-out': 1,
#          'sad': 1,
#          'safe': 2,
#          'salute': 1,
#          'same': 6,
#          'scattered': 1,
#          'schools': 1,
#          'seek': 2,
#          'seen': 1,
#          'serve': 1,
#          'share': 2,
#          'shine': 1,
#          'shores,': 1,
#          'should': 1,
#          'shuttered': 1,
#          'sights,': 1,
#          'simple': 1,
#          'sky,': 1,
#          'small': 2,
#          'so': 3,
#          'soldiers': 1,
#          'solidarity.': 1,
#          'souls,': 1,
#          'space,': 1,
#          'speak': 1,
#          'special': 1,
#          'spent': 1,
#          'spirit': 1,
#          'sprawl': 1,
#          'stand': 1,
#          'start': 1,
#          'starting': 1,
#          'states': 2,
#          'stealing': 1,
#          'steps': 1,
#          'stir': 1,
#          'stolen': 1,
#          'stops': 2,
#          'strength,': 1,
#          'strength.': 1,
#          'striving.': 1,
#          'strong': 1,
#          'struggling': 1,
#          'students': 1,
#          'subsidized': 1,
#          'success': 1,
#          'success.': 1,
#          'system,': 1,
#          'take': 1,
#          'talk': 2,
#          'taxes,': 1,
#          'technologies': 1,
#          'tell': 1,
#          'tells': 1,
#          'tens': 1,
#          'terrorism,': 1,
#          'thank': 2,
#          'that': 8,
#          'the': 70,
#          'their': 11,
#          'themselves.': 1,
#          'then': 1,
#          'there': 3,
#          'these': 3,
#          'they': 5,
#          'think': 1,
#          'this': 9,
#          'this,': 1,
#          'thought': 1,
#          'thrive': 1,
#          'through': 1,
#          'throughout': 1,
#          'time': 2,
#          'to': 37,
#          'today': 4,
#          'today’s': 1,
#          'together': 1,
#          'together,': 3,
#          'tombstones': 1,
#          'tomorrow.': 1,
#          'too': 3,
#          'total': 1,
#          'totally': 1,
#          'trade,': 1,
#          'transfer': 1,
#          'transferring': 2,
#          'transition.': 1,
#          'trapped': 1,
#          'trillions': 1,
#          'triumphs': 1,
#          'triumphs;': 1,
#          'truly': 1,
#          'tunnels,': 1,
#          'two': 1,
#          'understand': 1,
#          'understanding': 1,
#          'unite': 1,
#          'united': 2,
#          'united,': 1,
#          'unity.”': 1,
#          'unlock': 1,
#          'unrealized': 1,
#          'unstoppable.': 1,
#          'up': 1,
#          'upon': 1,
#          'urban': 1,
#          'us': 1,
#          'us,': 1,
#          'very': 2,
#          'victories': 1,
#          'victories;': 1,
#          'vision': 1,
#          'voice,': 1,
#          'want': 1,
#          'was': 1,
#          'washington': 1,
#          'washington,': 1,
#          'watching': 1,
#          'way': 1,
#          'way.': 1,
#          'we': 45,
#          'we,': 1,
#          'wealth': 1,
#          'wealth,': 1,
#          'wealth.': 2,
#          'wealthy': 1,
#          'welfare': 1,
#          'we’ve': 3,
#          'what': 1,
#          'when': 3,
#          'whether': 3,
#          'which': 4,
#          'while': 6,
#          'white,': 1,
#          'who': 1,
#          'will': 40,
#          'windswept': 1,
#          'winning': 2,
#          'wisdom': 1,
#          'with': 8,
#          'women': 2,
#          'wonderful': 1,
#          'words:': 1,
#          'work': 1,
#          'workers': 2,
#          'world': 4,
#          'world.': 1,
#          'world:': 1,
#          'years': 1,
#          'years,': 1,
#          'yes,': 1,
#          'you': 7,
#          'you,': 3,
#          'you.': 2,
#          'young': 1,
#          'your': 11,
#          '–': 12,
#          '“how': 1})

# %%
c.most_common(10)  #最常出現前十名
# Out:
# [('and', 72),
#  ('the', 70),
#  ('our', 48),
#  ('of', 48),
#  ('we', 45),
#  ('will', 40),
#  ('to', 37),
#  ('is', 21),
#  ('for', 16),
#  ('a', 15)]

# %%
#移除停止詞
for sw in stop_words:
    del c[sw]

# %%
c.most_common(10)
# Out:
# [('–', 12),
#  ('american', 11),
#  ('america', 10),
#  ('again.', 8),
#  ('one', 7),
#  ('every', 7),
#  ('country', 6),
#  ('new', 6),
#  ('back', 6),
#  ('great', 6)]
